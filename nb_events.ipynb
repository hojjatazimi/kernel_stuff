# %%
import get_events_from_snirf

# %%
get_events_from_snirf.get_events_from_snirf('../data_hojjat/retinostopy/s1/1/test_001_S001_35d961a_5.snirf', False)
# Out:
#      Timestamp            Event    Duration  Value  Block BlockType  \
# 0    34.605083  StartExperiment  400.957731    1.0    NaN       NaN
# 1    34.624174        StartRest   20.018307    1.0    NaN       NaN
# 2    54.642591       StartBlock   10.030220    1.0    1.0        Lr
# 3    64.689521        StartRest   15.012925    1.0    NaN       NaN
# 4    79.703429       StartBlock   10.036839    1.0    2.0        Ul
# 5    89.757274        StartRest   15.013242    1.0    NaN       NaN
# 6   104.770656       StartBlock   10.021088    1.0    3.0        Ll
# 7   114.808716        StartRest   15.013761    1.0    NaN       NaN
# 8   129.822682       StartBlock   10.040326    1.0    4.0        Ur
# 9   139.878712        StartRest   15.011750    1.0    NaN       NaN
# 10  154.890530       StartBlock   10.024549    1.0    5.0        Ll
# 11  164.931554        StartRest   15.014923    1.0    NaN       NaN
# 12  179.946573       StartBlock   10.038132    1.0    6.0        Ul
# ...

# %%
get_events_from_snirf.get_events_from_snirf('../data_hojjat/dec_nef/1_new_full_2/test_001_S001_c7bcdc0_5.snirf', True)
# Out:
#       Timestamp            Event    Duration  Value  Experiment  \
# 0     22.644750  StartExperiment  575.932999    1.0         1.0
# 1     22.691047             Stim    0.000000    1.0         1.0
# 2     23.657696             Stim    0.000000    1.0         1.0
# 3     24.591449             Stim    0.000000    1.0         1.0
# 4     25.542362             Stim    0.000000    1.0         1.0
# ..          ...              ...         ...    ...         ...
# 596  593.856994             Stim    0.000000    1.0         1.0
# 597  594.807750             Stim    0.000000    1.0         1.0
# 598  595.758414             Stim    0.000000    1.0         1.0
# 599  596.709954             Stim    0.000000    1.0         1.0
# 600  597.659994             Stim    0.000000    1.0         1.0
#
#                       Stim      Label         File  Counts  Block
# 0                      NaN         na          nan     0.0  False
# ...

# %%
get_events_from_snirf.get_events_from_snirf('data_hojjat/test_001_S001_f6cb9a6_5.snirf')

# %%
from time import sleep

# %%
sleep(10)

# %%
get_events_from_snirf.get_events_from_snirf('data_hojjat/at/at6.snirf')

# %%
get_events_from_snirf.get_events_from_snirf('data_hojjat/at/at8.snirf')

# %%
df = get_events_from_snirf.get_events_from_snirf('data_hojjat/dec_nef/test_001_S001_4e1faca_3.snirf')

# %%
df.head()

# %%
df['lable'] = [str(x)[: int(str(x).find('-'))] for x in df.Stim]

# %%
df

# %%
df['Sample'] = [round(x * 7.14) for x in df.Timestamp ]

# %%
df

# %%
df[df['lable'] == 'Bat']['Sample'].values
